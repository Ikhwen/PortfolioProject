# %% [markdown]
# <a href="https://colab.research.google.com/github/Ikhwen/PortfolioProject/blob/main/Youtube_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Part 1: Working with API in Python

# %% [markdown]
# Summary
#
# 1) Work with pyhton request and googleapiclient library to make API call
#
# 2) Make API call to Youtube API
#
# 3) Collected data as JSON
#
# 4)Saved data as pandas dataframe
#
# 5) Restructuring with Software Engineeering Fundamentals

# %%
#import libraries
import pandas as pd
import requests
import time
from google.colab import drive
from googleapiclient.discovery import build
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Read through the youtube API documents to understand the parameters to make API call
#
# [*Youtube API Reference*](https://developers.google.com/youtube/v3/docs/videos)

# %%
# Set API key
API_KEY = "AIzaSyBYSwJzj6QSOLvr9l7jCacGDe_AyYBGiA0"
# Set youtube variable using build function
youtube = build('youtube', 'v3',developerKey=API_KEY)

# %%
#API call using build funtion 
#You need to use snippets property for youtube search as it contains the basic information of the channel.
snippets = youtube.search().list(part="snippet",type="channel",q="Joma Tech").execute()
snippets['items'][0]['id']
# Out:
# {'channelId': 'UCV0qA-eDDICsRR9rPcnG7tw', 'kind': 'youtube#channel'}

# %%
#setting the channelID
CHANNEL_ID = "UCV0qA-eDDICsRR9rPcnG7tw" #Joma Tech channelID

# %%
#1st API call using request function
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken #from section = search,  part = snippet and id

response = requests.get(url).json()

# %%
response
# Out:
# {'etag': 'Ihez19B9_kxMlJLzUfmKjoSiWqk',
#  'items': [{'etag': '1Xycf0dpxG0ZEjyT1zxlvYJ7hdQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'YBYI7E2PqWE'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCV0qA-eDDICsRR9rPcnG7tw',
#     'channelTitle': 'Joma Tech',
#     'description': 'Go to https://NordVPN.com/joma to get 73% of the 2-year plan and 1 month free! (Lasts until Black Friday) Video courses from JomaClass: New to ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-26T06:14:53Z',
#     'publishedAt': '2021-11-26T06:14:53Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/YBYI7E2PqWE/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/YBYI7E2PqWE/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/YBYI7E2PqWE/mqdefault.jpg',
#       'width': 320}},
# ...

# %%
response['items'][0]
# Out:
# {'etag': '1Xycf0dpxG0ZEjyT1zxlvYJ7hdQ',
#  'id': {'kind': 'youtube#video', 'videoId': 'YBYI7E2PqWE'},
#  'kind': 'youtube#searchResult',
#  'snippet': {'channelId': 'UCV0qA-eDDICsRR9rPcnG7tw',
#   'channelTitle': 'Joma Tech',
#   'description': 'Go to https://NordVPN.com/joma to get 73% of the 2-year plan and 1 month free! (Lasts until Black Friday) Video courses from JomaClass: New to ...',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2021-11-26T06:14:53Z',
#   'publishedAt': '2021-11-26T06:14:53Z',
#   'thumbnails': {'default': {'height': 90,
#     'url': 'https://i.ytimg.com/vi/YBYI7E2PqWE/default.jpg',
#     'width': 120},
#    'high': {'height': 360,
#     'url': 'https://i.ytimg.com/vi/YBYI7E2PqWE/hqdefault.jpg',
#     'width': 480},
#    'medium': {'height': 180,
#     'url': 'https://i.ytimg.com/vi/YBYI7E2PqWE/mqdefault.jpg',
#     'width': 320}},
#   'title': 'If Squid Game were about Programmers'}}

# %%
video_id = response['items'][0]['id']['videoId']
video_id
# Out:
# 'YBYI7E2PqWE'

# %%
video_title = response['items'][0]['snippet']['title']
video_title = str(video_title).replace("&#39;","'")
video_title
# Out:
# 'If Squid Game were about Programmers'

# %%
upload_date = response['items'][0]['snippet']['publishedAt']
upload_date = str(upload_date).split("T")[0]
upload_date
# Out:
# '2021-11-26'

# %%
#Collect all teh details for each video using for-if loop

for video in response['items']:
  if video['id']['kind'] == "youtube#video" :             #making sure it's a youtube video
    video_id = video['id']['videoId']                     #replacing response['items][0] with video placeholder
    video_title = video['snippet']['title']
    video_title = str(video_title).replace("&#39;","'")
    upload_date = video['snippet']['publishedAt']
    upload_date = str(upload_date).split("T")[0]

    print(video_id)
    print(video_title)
    print(upload_date)
# Out:
# YBYI7E2PqWE
# If Squid Game were about Programmers
# 2021-11-26
# 7ZcmboYbNPQ
# How these pins helped the police fight crime with Data Science
# 2021-11-02
# 1fPWr0d5zBE
# 10 years of coding in 13 minutes
# 2021-10-19
# PY8f1Z3nARo
# chill lofi beats to code/relax to
# 2021-10-13
# lpcpsCY4Mco
# how programmers attend meetings at big tech companies
# 2021-09-02
# Hv6EMd8dlQk
# if Apple made Window Blinds
# 2021-08-06
# Rgx8dpiPwpA
# a day in the life of an engineer working from home
# 2021-05-23
# Nb5yppVh_4A
# Twitch founder who sold for $970 million chats with a guy with $970 in his bank account
# 2021-04-03
# -UdWguw90g4
# I Built a Trading Bot to let Subscribers Trade $25,000 on Twitch
# 2021-03-16
# X34ZmkeZDos
# Why Microsoft Word is the best IDE for programming
# 2021-02-10
# qiE7VKRHSsA
# If Chess Was An Anime
# 2021-01-11
# sW9npZVpiMI
# why you NEED math for programming
# 2021-01-06
# 0oBi8OmjLIg
# My Ultimate Work From Home Desk Setup for Productivity
# 2020-10-25
# ...

# %%
video_id_joma = "Z0N7vqSgRBY"
url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id_joma+"&part=statistics&key="+API_KEY
response_video_stats = requests.get(url_video_stats).json()
response_video_stats
# Out:
# {'etag': 'QX6nRT87Y-ES_044triXwCi-Tuo',
#  'items': [{'etag': 'sfUfBimfavuInOZVnaV0Ys1-KSs',
#    'id': 'Z0N7vqSgRBY',
#    'kind': 'youtube#video',
#    'statistics': {'dislikeCount': '1942',
#     'favoriteCount': '0',
#     'likeCount': '19285',
#     'viewCount': '456791'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
for video in response['items']:
  if video['id']['kind'] == "youtube#video" :             #making sure it's a youtube video
    video_id = video['id']['videoId']                     #replacing response['items][0] with video placeholder
    video_title = video['snippet']['title']
    video_title = str(video_title).replace("&#39;","'")
    upload_date = video['snippet']['publishedAt']
    upload_date = str(upload_date).split("T")[0]

    #collecting view, like, dislike, comment counts
    #2nd API call
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']

  #sometimes the creator turns off the comment section so therefore key "commentCount" can be mising; prompt a Keyerror
    try:
      comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    except:
      comment_count = response_video_stats.get('commentCount', 0)       

    #print
    print(video_id)
    print(video_title)
    print(upload_date)
    print(view_count)
    print(like_count)
    print(dislike_count)
    print(comment_count)
# Out:
# YBYI7E2PqWE
# If Squid Game were about Programmers
# 2021-11-26
# 451628
# 33795
# 633
# 1112
# 7ZcmboYbNPQ
# How these pins helped the police fight crime with Data Science
# 2021-11-02
# 396424
# 33281
# 227
# 1656
# 1fPWr0d5zBE
# 10 years of coding in 13 minutes
# 2021-10-19
# 1779867
# 94387
# 1140
# 3133
# PY8f1Z3nARo
# chill lofi beats to code/relax to
# 2021-10-13
# 507031
# 12144
# 175
# 0
# lpcpsCY4Mco
# how programmers attend meetings at big tech companies
# 2021-09-02
# 2822660
# 101282
# 1014
# 1966
# Hv6EMd8dlQk
# if Apple made Window Blinds
# 2021-08-06
# 1947870
# 120468
# 1612
# 4854
# Rgx8dpiPwpA
# a day in the life of an engineer working from home
# 2021-05-23
# 9483267
# 292236
# 4890
# 10612
# Nb5yppVh_4A
# Twitch founder who sold for $970 million chats with a guy with $970 in his bank account
# 2021-04-03
# 636782
# 18903
# 207
# 1132
# -UdWguw90g4
# I Built a Trading Bot to let Subscribers Trade $25,000 on Twitch
# 2021-03-16
# 2560988
# 100106
# 1148
# 7091
# ...

# %%
# build an empty dataframe containing all the variables
df = pd.DataFrame(columns=['video_id','video_title','upload_date','view_count','like_count','dislike_count','comment_count'])

# %%
#adding the for loop through append()

for video in response['items']:
  if video['id']['kind'] == "youtube#video" :             #making sure it's a youtube video
    video_id = video['id']['videoId']                     #replacing response['items][0] with video placeholder
    video_title = video['snippet']['title']
    video_title = str(video_title).replace("&#39;","'")
    upload_date = video['snippet']['publishedAt']
    upload_date = str(upload_date).split("T")[0]

    #collecting view, like, dislike, comment counts
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
    try:
      comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    except:
      comment_count = response_video_stats.get('commentCount', 0)

    #save data in pandas df
    df= df.append({'video_id':video_id,'video_title':video_title,'upload_date':upload_date,'view_count':view_count,
                   'like_count':like_count,'dislike_count':dislike_count,'comment_count':comment_count}, ignore_index=True)

# %%
df.head()
# Out:
#       video_id  ... comment_count
# 0  YBYI7E2PqWE  ...          1112
# 1  7ZcmboYbNPQ  ...          1656
# 2  1fPWr0d5zBE  ...          3133
# 3  PY8f1Z3nARo  ...             0
# 4  lpcpsCY4Mco  ...          1966
#
# [5 rows x 7 columns]

# %% [markdown]
# Restructuring code based on function

# %%
#defining a function
def get_video_details(video_id):

    #collecting view, like, dislike, comment counts
    #2nd API call
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
    try:
      comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    except:
      comment_count = response_video_stats.get('commentCount', 0)

    return view_count, like_count, dislike_count, comment_count

# %%
def get_videos(df):
  #1st API Call
  pageToken = ""
  url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken #from section = search,  part = snippet and id
  
  response = requests.get(url).json()
  time.sleep(1) #wait 1 seconf make enough time from API to get into response variable

  for video in response['items']:
    if video['id']['kind'] == "youtube#video" :             #making sure it's a youtube video
      video_id = video['id']['videoId']                     #replacing response['items][0] with video placeholder
      video_title = video['snippet']['title']
      video_title = str(video_title).replace("&#39;","'")
      upload_date = video['snippet']['publishedAt']
      upload_date = str(upload_date).split("T")[0]

      view_count, like_count, dislike_count, comment_count = get_video_details(video_id) #calling the variables again so it will run through the get_video_details function

      #save data in pandas df
      df= df.append({'video_id':video_id,'video_title':video_title,'upload_date':upload_date,'view_count':view_count,
                     'like_count':like_count,'dislike_count':dislike_count,'comment_count':comment_count}, ignore_index=True)
  return df

# %%
#main

#build our dataframe
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","dislike_count","comment_count"]) 

df = get_videos(df)

# %%
df
# Out:
#        video_id  ... comment_count
# 0   YBYI7E2PqWE  ...          1112
# 1   7ZcmboYbNPQ  ...          1656
# 2   1fPWr0d5zBE  ...          3133
# 3   PY8f1Z3nARo  ...             0
# 4   lpcpsCY4Mco  ...          1966
# 5   Hv6EMd8dlQk  ...          4854
# 6   Rgx8dpiPwpA  ...         10612
# 7   Nb5yppVh_4A  ...          1132
# 8   -UdWguw90g4  ...          7091
# 9   X34ZmkeZDos  ...          5666
# 10  qiE7VKRHSsA  ...          1380
# 11  sW9npZVpiMI  ...          7518
# 12  0oBi8OmjLIg  ...          3587
# 13  Z0N7vqSgRBY  ...             0
# 14  OTfp2_SwxHk  ...          4757
# 15  0KmUoTfGa34  ...          5238
# 16  vT3GUKuAzIs  ...          2165
# 17  pKO9UjSeLew  ...         14146
# 18  rR4n-0KYeKQ  ...          5737
# 19  HTXTVfBCeSY  ...          1848
# 20  pvimAM_SLic  ...          2046
# 21  jlieOSX3GyM  ...           162
# 22  1stFeRlvicI  ...           200
# 23  4cDCl4cS5xY  ...           127
# 24  vmYaAzbv9xk  ...           358
# 25  uHt01D6rOLI  ...          3131
# ...

# %% [markdown]
# Collecting all video details from every page utilizing page token variable

# %%
#defining a function
def get_video_details(video_id):

    #collecting view, like, dislike, comment counts
    #2nd API call
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
    try:
      comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    except:
      comment_count = response_video_stats.get('commentCount', 0)

    return view_count, like_count, dislike_count, comment_count

# %%
def get_videos(df):
    pageToken = ""
    while 1:
        url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken

        response = requests.get(url).json()
        time.sleep(1) #give it a second before starting the for loop
        for video in response['items']:
            if video['id']['kind'] == "youtube#video":
                video_id = video['id']['videoId']
                video_title = video['snippet']['title']
                video_title = str(video_title).replace("&amp;","")
                upload_date = video['snippet']['publishedAt']
                upload_date = str(upload_date).split("T")[0]
                view_count, like_count, dislike_count, comment_count = get_video_details(video_id)

                df = df.append({'video_id':video_id,'video_title':video_title,
                                "upload_date":upload_date,"view_count":view_count,
                                "like_count":like_count,"dislike_count":dislike_count,
                                "comment_count":comment_count},ignore_index=True)
        try:
            if response['nextPageToken'] != None: #if none, it means it reached the last page and break out of it
                pageToken = "pageToken=" + response['nextPageToken']

        except:
            break


    return df

# %%
#main

#build our dataframe
df2 = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","dislike_count","comment_count"]) 

df2 = get_videos(df2)

# %%
df2
# Out:
#        video_id  ... comment_count
# 0   YBYI7E2PqWE  ...          1112
# 1   7ZcmboYbNPQ  ...          1656
# 2   1fPWr0d5zBE  ...          3133
# 3   PY8f1Z3nARo  ...             0
# 4   lpcpsCY4Mco  ...          1966
# ..          ...  ...           ...
# 88  hGDJkqESz0k  ...           898
# 89  GXKI84KKVI8  ...           214
# 90  t6lBeG5QaC4  ...           664
# 91  02AXP5eI6PE  ...           315
# 92  kZC12U6EhTc  ...          1409
#
# [93 rows x 7 columns]

# %% [markdown]
# #Part 2 : Importing df to db

# %%
#installing and import postgreSQL database adapter
# !pip install psycopg2
import psycopg2 as ps

# %%
#connect to database by defining into a fuction and raise if error prompt

def connect_to_db(host_name, dbname, port, username, password):
    try:
        conn = ps.connect(host=host_name, database=dbname, user=username, password=password, port=port)

    except ps.OperationalError as e:
        raise e
    else:
        print('Connected!')
        return conn

# %%
#setting up credentials variables
host_name = 'database-yt.cxiqhmynrkc0.ap-southeast-1.rds.amazonaws.com'
dbname = 'postgres'
port = '5432'
username = 'IkhwanDB'
password = 'Megaxs1st*'
conn = None

#funtion to connect to db
conn = connect_to_db(host_name, dbname, port, username, password)
# Out:
# Connected!

# %%
#create a database table using SQL into a function

def create_table(curr):
    create_table_command = ( """ CREATE TABLE IF NOT EXISTS videos(
                      video_id VARCHAR(255) PRIMARY KEY,
                      video_title TEXT NOT NULL,
                      upload_date DATE NOT NULL DEFAULT CURRENT_DATE,
                      view_count INTEGER NOT NULL,
                      like_count INTEGER NOT NULL,
                      dislike_count INTEGER NOT NULL,
                      comment_count INTEGER NOT NULL
  )""")

    curr.execute(create_table_command)

# %%
#cursor method allows run sql command and fetch result from db / allow python run sql
curr = conn.cursor()

# %%
#execute a create_table function
create_table(curr)

# %%
#look at backend
#commit() the code = to end your current transaction and make permanent all changes performed in the transaction

conn.commit()

# %% [markdown]
# #Part 3: Populate the table in database

# %% [markdown]
# Pseudocode as a guideline for approach

# %%
#create guildeline to build a structure 

##updating the database
##handling data for scalability (as data grows, update cmd and insert cmd grows)
##check to see if video exists or dont exist
##perform update on existing videos
##perform insert on new existing videos into an temp df "new videos"
##perform insert df "new videos" into db

#psudeocode

for i,row in df.iterrows(): #for loop in df use iterrows method "i" is the index "row" is the row variable
      if check_if_video_exists(): # checking if exist in df and db
          update_row() # If video exist, then we will update in in db
      else: #If video doesnt exist we will append to the db table
          tmp_df = tmp_df.append(row)

# %%
##define a function to check to see if video exists 
def check_if_video_exists(curr, video_id): 
    query = ("""SELECT video_id FROM videos WHERE video_id = %s""") #Placeholder  %s for string

    curr.execute(query, (video_id,)) #passing tuple video_id as a parameter 
    return curr.fetchone() is not None #return a single row from a table which is not none

##define an update function to check to see if video does exist then update to db table
def update_row(curr, video_id,video_title,view_count,like_count,dislike_count,comment_count ):
      query = ("""UPDATE videos(
                SET video_title = %s,
                    view_count = %s,
                    like_count = %s,
                    dislike_count = %s,
                    comment_count = $s
                WHERE video_id = %s;""") #video_id as the primary key

      #create a variable tuple for those columns
      vars_to_update = (video_title,view_count,like_count,dislike_count,comment_count)
      curr.execute(query, vars_to_update)

##define main function (including new videos append to temp df)
def update_db(curr,df2):
    tmp_df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","dislike_count","comment_count"]) #tmp df for new videos

    for i,row in df2.iterrows(): #for loop in df use iterrows method "i" is the index "row" is the row variable
          if check_if_video_exists(curr, row['video_id']): # checking if exist in df and db
            update_row(curr, row['video_id'], row['video_title'],row['view_count'],row['like_count'],row['dislike_count'],row['comment_count'],) # If video exist, then we will update in in db
          else: #If video doesnt exist we will append to the db table
            tmp_df = tmp_df.append(row) 

    return tmp_df

# %%
#variable to store the update_db
new_vid_df = update_db(curr,df2)

# %%
conn.commit()

# %% [markdown]
# It will return all since db is empty

# %%
new_vid_df
# Out:
#        video_id  ... comment_count
# 0   YBYI7E2PqWE  ...          1112
# 1   7ZcmboYbNPQ  ...          1656
# 2   1fPWr0d5zBE  ...          3133
# 3   PY8f1Z3nARo  ...             0
# 4   lpcpsCY4Mco  ...          1966
# ..          ...  ...           ...
# 88  hGDJkqESz0k  ...           898
# 89  GXKI84KKVI8  ...           214
# 90  t6lBeG5QaC4  ...           664
# 91  02AXP5eI6PE  ...           315
# 92  kZC12U6EhTc  ...          1409
#
# [93 rows x 7 columns]

# %%
#Insert funtion similar to update_row
def insert_into_table(curr, video_id, video_title, upload_date, view_count, like_count, dislike_count, comment_count):
    insert_into_videos = ("""INSERT INTO videos (video_id, video_title, upload_date,
                        view_count, like_count, dislike_count,comment_count)
    VALUES(%s,%s,%s,%s,%s,%s,%s);""")
    row_to_insert = (video_id, video_title, upload_date, view_count, like_count, dislike_count, comment_count)
    curr.execute(insert_into_videos, row_to_insert)

#for loop so we insert one video at a time, performance memory problems might arise
def append_from_df_to_db(curr,df2):
    for i, row in df2.iterrows(): 
        insert_into_table(curr, row['video_id'], row['video_title'], row['upload_date'], row['view_count']
                          , row['like_count'], row['dislike_count'], row['comment_count'])

# %%
append_from_df_to_db(curr,new_vid_df)

# %%
conn.commit()

# %% [markdown]
# Next Part: Scheduler?
